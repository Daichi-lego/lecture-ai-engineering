# %% [markdown]
# # 実践演習 Day 1：streamlitとFastAPIのデモ
# このノートブックでは以下の内容を学習します。
#
# - 必要なライブラリのインストールと環境設定
# - Hugging Faceからモデルを用いたStreamlitのデモアプリ
# - FastAPIとngrokを使用したAPIの公開方法
#
# 演習を始める前に、HuggingFaceとngrokのアカウントを作成し、
# それぞれのAPIトークンを取得する必要があります。
#
#
# 演習の時間では、以下の3つのディレクトリを順に説明します。
#
# 1. 01_streamlit_UI
# 2. 02_streamlit_app
# 3. 03_FastAPI
#
# 2つ目や3つ目からでも始められる様にノートブックを作成しています。
#
# 復習の際にもこのノートブックを役立てていただければと思います。
#
# ### 注意事項
# 「02_streamlit_app」と「03_FastAPI」では、GPUを使用します。
#
# これらを実行する際は、Google Colab画面上のメニューから「編集」→ 「ノートブックの設定」
#
# 「ハードウェアアクセラレーター」の項目の中から、「T4 GPU」を選択してください。
#
# このノートブックのデフォルトは「CPU」になっています。
#
# ---

# %% [markdown]
# # 環境変数の設定（1~3共有）

# %% [markdown]
# GitHubから演習用のコードをCloneします。

# %%
# !git clone https://github.com/matsuolab/lecture-ai-engineering.git

# %% [markdown]
# 必要なAPIトークンを.envに設定します。
#
# 「lecture-ai-engineering/day1」の配下に、「.env_template」ファイルが存在しています。
#
# 隠しファイルのため表示されていない場合は、画面左側のある、目のアイコンの「隠しファイルの表示」ボタンを押してください。
#
# 「.env_template」のファイル名を「.env」に変更します。「.env」ファイルを開くと、以下のような中身になっています。
#
#
# ```
# HUGGINGFACE_TOKEN="hf-********"
# NGROK_TOKEN="********"
# ```
# ダブルクオーテーションで囲まれた文字列をHuggingfaceのアクセストークンと、ngrokの認証トークンで書き変えてください。
#
# それぞれのアカウントが作成済みであれば、以下のURLからそれぞれのトークンを取得できます。
#
# - Huggingfaceのアクセストークン
# https://huggingface.co/docs/hub/security-tokens
#
# - ngrokの認証トークン
# https://dashboard.ngrok.com/get-started/your-authtoken
#
# 書き換えたら、「.env」ファイルをローカルのPCにダウンロードしてください。
#
# 「01_streamlit_UI」から「02_streamlit_app」へ進む際に、CPUからGPUの利用に切り替えるため、セッションが一度切れてしまいます。
#
# その際に、トークンを設定した「.env」ファイルは再作成することになるので、その手間を減らすために「.env」ファイルをダウンロードしておくと良いです。

# %% [markdown]
# 「.env」ファイルを読み込み、環境変数として設定します。次のセルを実行し、最終的に「True」が表示されていればうまく読み込めています。

# %%
# !pip install python-dotenv
from dotenv import load_dotenv, find_dotenv

# %cd /content/lecture-ai-engineering/day1
load_dotenv(find_dotenv())

# %% [markdown]
# # 01_streamlit_UI
#
# ディレクトリ「01_streamlit_UI」に移動します。

# %%
# %cd /content/lecture-ai-engineering/day1/01_streamlit_UI

# %% [markdown]
# 必要なライブラリをインストールします。

# %%
# %%capture
# !pip install -r requirements.txt

# %% [markdown]
# ngrokのトークンを使用して、認証を行います。

# %%
# !ngrok authtoken $$NGROK_TOKEN

# %% [markdown]
# アプリを起動します。

# %%
from pyngrok import ngrok

public_url = ngrok.connect(8501).public_url
print(f"公開URL: {public_url}")
# !streamlit run app.py

# %% [markdown]
# 公開URLの後に記載されているURLにブラウザでアクセスすると、streamlitのUIが表示されます。
#
# app.pyのコメントアウトされている箇所を編集することで、UIがどの様に変化するか確認してみましょう。
#
# streamlitの公式ページには、ギャラリーページがあります。
#
# streamlitを使うとpythonという一つの言語であっても、様々なUIを実現できることがわかると思います。
#
# https://streamlit.io/gallery

# %% [markdown]
# 後片付けとして、使う必要のないngrokのトンネルを削除します。

# %%
from pyngrok import ngrok
ngrok.kill()

# %% [markdown]
# # 02_streamlit_app

# %% [markdown]
# ディレクトリ「02_streamlit_app」に移動します。

# %%
# %cd /content/lecture-ai-engineering/day1/02_streamlit_app

# %% [markdown]
# 必要なライブラリをインストールします。

# %%
# %%capture
# !pip install -r requirements.txt

# %% [markdown]
# ngrokとhuggigfaceのトークンを使用して、認証を行います。

# %%
# !ngrok authtoken $$NGROK_TOKEN
# !huggingface-cli login --token $$HUGGINGFACE_TOKEN

# %% [markdown]
# stramlitでHuggingfaceのトークン情報を扱うために、streamlit用の設定ファイル（.streamlit）を作成し、トークンの情報を格納します。

# %%
# .streamlit/secrets.toml ファイルを作成
import os
import toml

# 設定ファイルのディレクトリ確保
os.makedirs('.streamlit', exist_ok=True)

# 環境変数から取得したトークンを設定ファイルに書き込む
secrets = {
    "huggingface": {
        "token": os.environ.get("HUGGINGFACE_TOKEN", "")
    }
}

# 設定ファイルを書き込む
with open('.streamlit/secrets.toml', 'w') as f:
    toml.dump(secrets, f)

# %% [markdown]
# アプリを起動します。
#
# 02_streamlit_appでは、Huggingfaceからモデルをダウンロードするため、初回起動には2分程度時間がかかります。
#
# この待ち時間を利用して、app.pyのコードを確認してみましょう。

# %%
from pyngrok import ngrok

public_url = ngrok.connect(8501).public_url
print(f"公開URL: {public_url}")
# !streamlit run app.py
# Out:
# 公開URL: https://021c-34-105-53-51.ngrok-free.app
#
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.105.53.51:8501
#
# NLTK loaded successfully.
# 2025-04-30 06:46:13.075652: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745995573.321149   14030 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745995573.390267   14030 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-30 06:46:13.924260: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# NLTK Punkt data checked/downloaded.
# NLTK Punkt data checked/downloaded.
# Database 'chat_feedback.db' initialized successfully.
# Database 'chat_feedback.db' initialized successfully.
# config.json: 100% 857/857 [00:00<00:00, 5.58MB/s]
# model.safetensors.index.json: 100% 39.1k/39.1k [00:00<00:00, 6.32MB/s]
# Fetching 4 files:   0% 0/4 [00:00<?, ?it/s]
# model-00002-of-00004.safetensors:   0% 0.00/4.95G [00:00<?, ?B/s]
#
# model-00004-of-00004.safetensors:   0% 0.00/3.67G [00:00<?, ?B/s]
#
#
# model-00001-of-00004.safetensors:   0% 0.00/4.90G [00:00<?, ?B/s]
#
#
#
# model-00003-of-00004.safetensors:   0% 0.00/4.96G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0% 10.5M/4.95G [00:00<00:56, 87.2MB/s]
#
#
# model-00001-of-00004.safetensors:   0% 10.5M/4.90G [00:00<01:00, 81.4MB/s]
#
# model-00004-of-00004.safetensors:   0% 10.5M/3.67G [00:00<00:53, 69.0MB/s]
#
#
#
# model-00003-of-00004.safetensors:   0% 10.5M/4.96G [00:00<01:11, 69.5MB/s]
# model-00002-of-00004.safetensors:   0% 21.0M/4.95G [00:00<00:56, 87.3MB/s]
#
#
# model-00001-of-00004.safetensors:   1% 31.5M/4.90G [00:00<00:46, 104MB/s]
#
#
#
# model-00003-of-00004.safetensors:   0% 21.0M/4.96G [00:00<01:13, 67.0MB/s]
#
# model-00004-of-00004.safetensors:   1% 21.0M/3.67G [00:00<00:58, 62.1MB/s]
#
#
# model-00001-of-00004.safetensors:   1% 41.9M/4.90G [00:00<00:50, 96.9MB/s]
# model-00002-of-00004.safetensors:   1% 41.9M/4.95G [00:00<00:56, 86.3MB/s]
#
# model-00004-of-00004.safetensors:   1% 31.5M/3.67G [00:00<01:01, 59.2MB/s]
#
#
#
# model-00003-of-00004.safetensors:   1% 41.9M/4.96G [00:00<01:02, 79.3MB/s]
#
#
# model-00001-of-00004.safetensors:   1% 52.4M/4.90G [00:00<00:59, 81.8MB/s]
# model-00002-of-00004.safetensors:   1% 52.4M/4.95G [00:00<01:02, 78.0MB/s]
#
# model-00004-of-00004.safetensors:   1% 41.9M/3.67G [00:00<00:58, 61.9MB/s]
#
#
# model-00001-of-00004.safetensors:   1% 62.9M/4.90G [00:00<00:56, 85.2MB/s]
#
#
#
# model-00003-of-00004.safetensors:   1% 62.9M/4.96G [00:00<00:52, 92.8MB/s]
# model-00002-of-00004.safetensors:   1% 73.4M/4.95G [00:00<00:51, 94.2MB/s]
#
#
#
# model-00003-of-00004.safetensors:   1% 73.4M/4.96G [00:00<00:53, 91.6MB/s]
#
#
# model-00001-of-00004.safetensors:   2% 83.9M/4.90G [00:00<00:47, 102MB/s]
#
# model-00004-of-00004.safetensors:   2% 62.9M/3.67G [00:00<00:48, 74.7MB/s]
#
#
# model-00001-of-00004.safetensors:   2% 94.4M/4.90G [00:00<00:47, 101MB/s]
# model-00002-of-00004.safetensors:   2% 94.4M/4.95G [00:01<00:53, 90.5MB/s]
#
#
#
# model-00003-of-00004.safetensors:   2% 94.4M/4.96G [00:01<00:53, 91.5MB/s]
#
#
# model-00001-of-00004.safetensors:   2% 105M/4.90G [00:01<00:50, 94.4MB/s]
#
# model-00004-of-00004.safetensors:   2% 83.9M/3.67G [00:01<00:43, 81.8MB/s]
#
#
# model-00001-of-00004.safetensors:   2% 115M/4.90G [00:01<00:57, 82.9MB/s]
#
# model-00004-of-00004.safetensors:   3% 94.4M/3.67G [00:01<00:46, 76.8MB/s]
# model-00002-of-00004.safetensors:   2% 115M/4.95G [00:01<00:55, 87.0MB/s]
#
#
#
# model-00003-of-00004.safetensors:   2% 115M/4.96G [00:01<00:55, 87.7MB/s]
#
# model-00004-of-00004.safetensors:   3% 105M/3.67G [00:01<00:43, 81.9MB/s]
# model-00002-of-00004.safetensors:   3% 126M/4.95G [00:01<01:05, 74.0MB/s]
#
#
#
# model-00003-of-00004.safetensors:   3% 126M/4.96G [00:01<01:03, 76.6MB/s]
#
#
# model-00001-of-00004.safetensors:   3% 136M/4.90G [00:01<01:00, 79.2MB/s]
#
# model-00004-of-00004.safetensors:   3% 115M/3.67G [00:01<00:50, 69.7MB/s]
# model-00002-of-00004.safetensors:   3% 147M/4.95G [00:01<01:02, 77.0MB/s]
#
# model-00004-of-00004.safetensors:   3% 126M/3.67G [00:01<00:54, 65.0MB/s]
#
#
#
# model-00003-of-00004.safetensors:   3% 147M/4.96G [00:01<01:05, 73.8MB/s]
#
#
# model-00001-of-00004.safetensors:   3% 157M/4.90G [00:01<01:03, 74.7MB/s]
#
# model-00004-of-00004.safetensors:   4% 136M/3.67G [00:01<00:50, 69.3MB/s]
# model-00002-of-00004.safetensors:   3% 157M/4.95G [00:01<01:04, 74.2MB/s]
#
#
#
# model-00003-of-00004.safetensors:   3% 157M/4.96G [00:01<01:02, 77.5MB/s]
#
#
# model-00001-of-00004.safetensors:   3% 168M/4.90G [00:02<01:06, 70.7MB/s]
#
# model-00004-of-00004.safetensors:   4% 147M/3.67G [00:02<00:50, 69.8MB/s]
# model-00002-of-00004.safetensors:   3% 168M/4.95G [00:02<01:06, 71.8MB/s]
#
#
#
# model-00003-of-00004.safetensors:   3% 168M/4.96G [00:02<01:07, 70.7MB/s]
#
#
# model-00001-of-00004.safetensors:   4% 178M/4.90G [00:02<01:12, 65.6MB/s]
#
# model-00004-of-00004.safetensors:   4% 157M/3.67G [00:02<00:58, 60.3MB/s]
# model-00002-of-00004.safetensors:   4% 178M/4.95G [00:02<01:16, 62.3MB/s]
#
#
#
# model-00003-of-00004.safetensors:   4% 178M/4.96G [00:02<01:16, 62.4MB/s]
#
#
# model-00001-of-00004.safetensors:   4% 189M/4.90G [00:02<01:19, 59.1MB/s]
#
# model-00004-of-00004.safetensors:   5% 168M/3.67G [00:02<01:01, 56.7MB/s]
# model-00002-of-00004.safetensors:   4% 189M/4.95G [00:02<01:24, 56.4MB/s]
#
#
#
# model-00003-of-00004.safetensors:   4% 189M/4.96G [00:02<01:25, 56.1MB/s]
#
#
# model-00001-of-00004.safetensors:   4% 199M/4.90G [00:02<01:27, 53.8MB/s]
#
# model-00004-of-00004.safetensors:   5% 178M/3.67G [00:02<01:07, 51.9MB/s]
# model-00002-of-00004.safetensors:   4% 199M/4.95G [00:02<01:32, 51.2MB/s]
#
#
#
# model-00003-of-00004.safetensors:   4% 199M/4.96G [00:02<01:32, 51.6MB/s]
#
#
# model-00001-of-00004.safetensors:   4% 210M/4.90G [00:03<01:39, 47.2MB/s]
#
# model-00004-of-00004.safetensors:   5% 189M/3.67G [00:03<01:19, 44.0MB/s]
# model-00002-of-00004.safetensors:   4% 210M/4.95G [00:03<01:50, 43.1MB/s]
#
#
#
# model-00003-of-00004.safetensors:   4% 210M/4.96G [00:03<01:56, 40.8MB/s]
#
#
# model-00001-of-00004.safetensors:   4% 220M/4.90G [00:16<29:27, 2.65MB/s]
#
# model-00004-of-00004.safetensors:   5% 199M/3.67G [00:16<23:18, 2.48MB/s]
# model-00002-of-00004.safetensors:   4% 220M/4.95G [00:16<30:29, 2.58MB/s]
#
#
#
# model-00003-of-00004.safetensors:   4% 220M/4.96G [00:17<31:06, 2.54MB/s]
#
#
# model-00001-of-00004.safetensors:   5% 231M/4.90G [00:17<22:15, 3.50MB/s]
# model-00002-of-00004.safetensors:   5% 231M/4.95G [00:17<22:20, 3.52MB/s]
#
# model-00004-of-00004.safetensors:   6% 210M/3.67G [00:17<16:59, 3.40MB/s]
#
#
#
# model-00003-of-00004.safetensors:   5% 241M/4.96G [00:17<17:23, 4.53MB/s]
# model-00002-of-00004.safetensors:   5% 241M/4.95G [00:17<16:07, 4.86MB/s]
#
#
# model-00001-of-00004.safetensors:   5% 252M/4.90G [00:17<12:35, 6.15MB/s]
#
# model-00004-of-00004.safetensors:   6% 231M/3.67G [00:17<09:25, 6.09MB/s]
# model-00002-of-00004.safetensors:   5% 252M/4.95G [00:17<11:40, 6.70MB/s]
#
#
#
# model-00003-of-00004.safetensors:   5% 252M/4.96G [00:17<13:28, 5.83MB/s]
#
# model-00004-of-00004.safetensors:   7% 252M/3.67G [00:17<05:52, 9.71MB/s]
#
#
# model-00001-of-00004.safetensors:   6% 273M/4.90G [00:17<07:57, 9.70MB/s]
#
#
#
# model-00003-of-00004.safetensors:   5% 262M/4.96G [00:17<10:16, 7.63MB/s]
# model-00002-of-00004.safetensors:   6% 273M/4.95G [00:17<06:37, 11.7MB/s]
#
# model-00004-of-00004.safetensors:   7% 262M/3.67G [00:17<04:41, 12.1MB/s]
#
#
# model-00001-of-00004.safetensors:   6% 283M/4.90G [00:17<06:24, 12.0MB/s]
#
#
#
# model-00003-of-00004.safetensors:   5% 273M/4.96G [00:17<07:44, 10.1MB/s]
# model-00002-of-00004.safetensors:   6% 283M/4.95G [00:17<05:16, 14.8MB/s]
#
# model-00004-of-00004.safetensors:   7% 273M/3.67G [00:17<03:42, 15.3MB/s]
#
#
# model-00001-of-00004.safetensors:   6% 294M/4.90G [00:17<05:04, 15.1MB/s]
#
#
#
# model-00003-of-00004.safetensors:   6% 283M/4.96G [00:17<05:52, 13.3MB/s]
#
# model-00004-of-00004.safetensors:   8% 283M/3.67G [00:17<02:53, 19.5MB/s]
# model-00002-of-00004.safetensors:   6% 294M/4.95G [00:17<04:08, 18.7MB/s]
#
# model-00004-of-00004.safetensors:   8% 294M/3.67G [00:18<02:16, 24.7MB/s]
#
#
#
# model-00003-of-00004.safetensors:   6% 294M/4.96G [00:18<04:30, 17.2MB/s]
# model-00002-of-00004.safetensors:   6% 304M/4.95G [00:18<03:21, 23.0MB/s]
#
#
# model-00001-of-00004.safetensors:   6% 315M/4.90G [00:18<03:24, 22.4MB/s]
#
#
#
# model-00003-of-00004.safetensors:   6% 304M/4.96G [00:18<03:27, 22.5MB/s]
#
# model-00004-of-00004.safetensors:   8% 304M/3.67G [00:18<01:51, 30.3MB/s]
# model-00002-of-00004.safetensors:   6% 315M/4.95G [00:18<02:41, 28.8MB/s]
#
# model-00004-of-00004.safetensors:   9% 315M/3.67G [00:18<01:30, 37.2MB/s]
#
#
# model-00001-of-00004.safetensors:   7% 336M/4.90G [00:18<02:26, 31.3MB/s]
#
#
#
# model-00003-of-00004.safetensors:   7% 325M/4.96G [00:18<02:14, 34.4MB/s]
# model-00002-of-00004.safetensors:   7% 336M/4.95G [00:18<01:45, 43.9MB/s]
#
# model-00004-of-00004.safetensors:   9% 325M/3.67G [00:18<01:14, 44.8MB/s]
# model-00002-of-00004.safetensors:   7% 346M/4.95G [00:18<01:32, 49.6MB/s]
#
#
# model-00001-of-00004.safetensors:   7% 357M/4.90G [00:18<01:52, 40.5MB/s]
#
# model-00004-of-00004.safetensors:   9% 336M/3.67G [00:18<01:09, 48.2MB/s]
#
#
#
# model-00003-of-00004.safetensors:   7% 346M/4.96G [00:18<01:41, 45.3MB/s]
# model-00002-of-00004.safetensors:   7% 357M/4.95G [00:18<01:24, 54.7MB/s]
#
#
# model-00001-of-00004.safetensors:   7% 367M/4.90G [00:18<01:42, 44.2MB/s]
#
# model-00004-of-00004.safetensors:   9% 346M/3.67G [00:18<01:09, 47.6MB/s]
#
#
#
# model-00003-of-00004.safetensors:   7% 357M/4.96G [00:18<01:40, 46.0MB/s]
# model-00002-of-00004.safetensors:   7% 367M/4.95G [00:20<03:46, 20.2MB/s]
#
# model-00004-of-00004.safetensors:  10% 357M/3.67G [00:20<02:47, 19.8MB/s]
#
#
#
# model-00003-of-00004.safetensors:   7% 367M/4.96G [00:20<03:29, 22.0MB/s]
#
#
# model-00001-of-00004.safetensors:   8% 377M/4.90G [00:20<03:34, 21.1MB/s]
#
# model-00004-of-00004.safetensors:  10% 367M/3.67G [00:20<02:07, 25.9MB/s]
#
#
#
# model-00003-of-00004.safetensors:   8% 377M/4.96G [00:20<02:47, 27.4MB/s]
# model-00002-of-00004.safetensors:   8% 377M/4.95G [00:20<03:03, 25.0MB/s]
#
#
# model-00001-of-00004.safetensors:   8% 388M/4.90G [00:20<02:59, 25.2MB/s]
# model-00002-of-00004.safetensors:   8% 388M/4.95G [00:20<02:24, 31.5MB/s]
#
#
#
# model-00003-of-00004.safetensors:   8% 388M/4.96G [00:20<02:19, 32.7MB/s]
#
# model-00004-of-00004.safetensors:  11% 388M/3.67G [00:20<01:25, 38.6MB/s]
#
#
# model-00001-of-00004.safetensors:   8% 398M/4.90G [00:20<02:31, 29.7MB/s]
#
#
#
# model-00003-of-00004.safetensors:   8% 398M/4.96G [00:20<02:06, 36.2MB/s]
#
# model-00004-of-00004.safetensors:  11% 398M/3.67G [00:20<01:18, 41.8MB/s]
# model-00002-of-00004.safetensors:   8% 398M/4.95G [00:20<02:17, 33.2MB/s]
#
#
# model-00001-of-00004.safetensors:   8% 409M/4.90G [00:20<02:13, 33.8MB/s]
#
#
#
# model-00003-of-00004.safetensors:   8% 409M/4.96G [00:20<01:44, 43.7MB/s]
#
# model-00004-of-00004.safetensors:  11% 409M/3.67G [00:20<01:11, 45.9MB/s]
#
#
# model-00001-of-00004.safetensors:   9% 419M/4.90G [00:20<01:59, 37.5MB/s]
# model-00002-of-00004.safetensors:   8% 409M/4.95G [00:20<02:13, 34.0MB/s]
#
#
#
# model-00003-of-00004.safetensors:   8% 419M/4.96G [00:21<02:07, 35.7MB/s]
#
# model-00004-of-00004.safetensors:  11% 419M/3.67G [00:21<01:22, 39.4MB/s]
#
#
# model-00001-of-00004.safetensors:   9% 430M/4.90G [00:21<02:01, 36.7MB/s]
# model-00002-of-00004.safetensors:   8% 419M/4.95G [00:21<02:09, 35.1MB/s]
#
#
#
# model-00003-of-00004.safetensors:   9% 430M/4.96G [00:21<01:43, 43.8MB/s]
#
# model-00004-of-00004.safetensors:  12% 430M/3.67G [00:21<01:11, 45.4MB/s]
#
#
# model-00001-of-00004.safetensors:   9% 440M/4.90G [00:21<01:44, 42.8MB/s]
#
#
#
# model-00003-of-00004.safetensors:   9% 440M/4.96G [00:21<01:27, 51.6MB/s]
# model-00002-of-00004.safetensors:   9% 430M/4.95G [00:21<01:51, 40.6MB/s]
#
# model-00004-of-00004.safetensors:  12% 440M/3.67G [00:21<00:59, 54.1MB/s]
#
#
# model-00001-of-00004.safetensors:   9% 451M/4.90G [00:21<01:26, 51.2MB/s]
#
#
# model-00001-of-00004.safetensors:   9% 461M/4.90G [00:21<01:33, 47.4MB/s]
#
#
#
# model-00003-of-00004.safetensors:   9% 461M/4.96G [00:21<01:21, 55.0MB/s]
# model-00002-of-00004.safetensors:   9% 451M/4.95G [00:21<01:47, 41.8MB/s]
#
# model-00004-of-00004.safetensors:  13% 461M/3.67G [00:21<01:07, 47.8MB/s]
# model-00002-of-00004.safetensors:   9% 461M/4.95G [00:21<01:33, 47.9MB/s]
#
#
# model-00001-of-00004.safetensors:  10% 472M/4.90G [00:21<01:42, 43.2MB/s]
#
#
#
# model-00003-of-00004.safetensors:  10% 472M/4.96G [00:21<01:31, 48.9MB/s]
#
# model-00004-of-00004.safetensors:  13% 472M/3.67G [00:21<00:59, 53.6MB/s]
#
# model-00004-of-00004.safetensors:  13% 482M/3.67G [00:22<00:58, 54.4MB/s]
# model-00002-of-00004.safetensors:  10% 482M/4.95G [00:22<01:19, 55.9MB/s]
#
#
#
# model-00003-of-00004.safetensors:  10% 493M/4.96G [00:22<01:19, 55.9MB/s]
#
#
# model-00001-of-00004.safetensors:  10% 493M/4.90G [00:22<01:25, 51.4MB/s]
#
# model-00004-of-00004.safetensors:  13% 493M/3.67G [00:23<02:34, 20.5MB/s]
# model-00002-of-00004.safetensors:  10% 493M/4.95G [00:23<03:11, 23.3MB/s]
#
#
#
# model-00003-of-00004.safetensors:  10% 503M/4.96G [00:23<03:10, 23.4MB/s]
#
#
# model-00001-of-00004.safetensors:  10% 503M/4.90G [00:23<03:26, 21.3MB/s]
#
# model-00004-of-00004.safetensors:  14% 503M/3.67G [00:23<02:00, 26.2MB/s]
# model-00002-of-00004.safetensors:  10% 503M/4.95G [00:23<02:35, 28.5MB/s]
#
#
#
# model-00003-of-00004.safetensors:  10% 514M/4.96G [00:23<02:35, 28.5MB/s]
#
#
# model-00001-of-00004.safetensors:  10% 514M/4.90G [00:23<02:48, 26.1MB/s]
#
# model-00004-of-00004.safetensors:  14% 524M/3.67G [00:23<01:18, 40.3MB/s]
# model-00002-of-00004.safetensors:  11% 524M/4.95G [00:23<01:47, 41.2MB/s]
#
#
# model-00001-of-00004.safetensors:  11% 524M/4.90G [00:23<02:18, 31.7MB/s]
#
#
#
# model-00003-of-00004.safetensors:  11% 535M/4.96G [00:23<01:51, 39.6MB/s]
#
# model-00004-of-00004.safetensors:  15% 535M/3.67G [00:23<01:09, 45.1MB/s]
# model-00002-of-00004.safetensors:  11% 535M/4.95G [00:24<01:37, 45.4MB/s]
#
#
#
# model-00003-of-00004.safetensors:  11% 545M/4.96G [00:24<01:40, 44.0MB/s]
#
#
# model-00001-of-00004.safetensors:  11% 535M/4.90G [00:24<01:59, 36.6MB/s]
#
# model-00004-of-00004.safetensors:  15% 545M/3.67G [00:24<01:00, 51.4MB/s]
# model-00002-of-00004.safetensors:  11% 545M/4.95G [00:24<01:27, 50.3MB/s]
#
# model-00004-of-00004.safetensors:  15% 556M/3.67G [00:24<00:52, 58.8MB/s]
#
#
#
# model-00003-of-00004.safetensors:  11% 556M/4.96G [00:24<01:28, 49.7MB/s]
#
#
# model-00001-of-00004.safetensors:  11% 545M/4.90G [00:24<01:39, 43.6MB/s]
# model-00002-of-00004.safetensors:  11% 566M/4.95G [00:24<01:05, 66.6MB/s]
#
#
#
# model-00003-of-00004.safetensors:  11% 566M/4.96G [00:24<01:18, 55.8MB/s]
#
# model-00004-of-00004.safetensors:  16% 577M/3.67G [00:24<00:47, 65.3MB/s]
#
#
# model-00001-of-00004.safetensors:  12% 566M/4.90G [00:24<01:20, 54.0MB/s]
# model-00002-of-00004.safetensors:  12% 577M/4.95G [00:24<01:09, 62.6MB/s]
#
#
#
# model-00003-of-00004.safetensors:  12% 577M/4.96G [00:24<01:19, 55.2MB/s]
#
#
# model-00001-of-00004.safetensors:  12% 577M/4.90G [00:24<01:17, 55.9MB/s]
#
# model-00004-of-00004.safetensors:  16% 587M/3.67G [00:24<00:49, 62.2MB/s]
# model-00002-of-00004.safetensors:  12% 587M/4.95G [00:24<01:11, 60.7MB/s]
#
#
#
# model-00003-of-00004.safetensors:  12% 587M/4.96G [00:24<01:20, 54.6MB/s]
#
#
# model-00001-of-00004.safetensors:  12% 587M/4.90G [00:24<01:15, 57.3MB/s]
#
#
#
# model-00003-of-00004.safetensors:  12% 598M/4.96G [00:24<01:11, 61.1MB/s]
#
# model-00004-of-00004.safetensors:  16% 598M/3.67G [00:24<00:51, 59.5MB/s]
# model-00002-of-00004.safetensors:  12% 598M/4.95G [00:24<01:10, 61.5MB/s]
#
#
# model-00001-of-00004.safetensors:  12% 598M/4.90G [00:25<01:24, 50.8MB/s]
#
#
#
# model-00003-of-00004.safetensors:  12% 608M/4.96G [00:25<01:25, 51.2MB/s]
#
# model-00004-of-00004.safetensors:  17% 608M/3.67G [00:25<01:02, 49.2MB/s]
# model-00002-of-00004.safetensors:  12% 608M/4.95G [00:25<01:35, 45.6MB/s]
#
#
# model-00001-of-00004.safetensors:  12% 608M/4.90G [00:27<05:17, 13.5MB/s]
#
#
#
# model-00003-of-00004.safetensors:  12% 619M/4.96G [00:27<05:31, 13.1MB/s]
# model-00002-of-00004.safetensors:  13% 619M/4.95G [00:27<05:12, 13.9MB/s]
#
#
# model-00001-of-00004.safetensors:  13% 619M/4.90G [00:27<03:59, 17.9MB/s]
#
#
#
# model-00003-of-00004.safetensors:  13% 629M/4.96G [00:27<04:07, 17.5MB/s]
# model-00002-of-00004.safetensors:  13% 629M/4.95G [00:27<03:59, 18.0MB/s]
#
# model-00004-of-00004.safetensors:  17% 619M/3.67G [00:27<03:56, 12.9MB/s]
#
#
#
# model-00003-of-00004.safetensors:  13% 640M/4.96G [00:27<03:10, 22.7MB/s]
# model-00002-of-00004.safetensors:  13% 640M/4.95G [00:27<03:06, 23.1MB/s]
#
#
# model-00001-of-00004.safetensors:  13% 640M/4.90G [00:27<02:31, 28.1MB/s]
#
# model-00004-of-00004.safetensors:  17% 629M/3.67G [00:27<03:00, 16.8MB/s]
#
#
#
# model-00003-of-00004.safetensors:  13% 650M/4.96G [00:27<02:28, 29.1MB/s]
# model-00002-of-00004.safetensors:  13% 650M/4.95G [00:27<02:25, 29.6MB/s]
#
#
# model-00001-of-00004.safetensors:  13% 650M/4.90G [00:27<02:04, 34.0MB/s]
#
# model-00004-of-00004.safetensors:  17% 640M/3.67G [00:27<02:17, 22.0MB/s]
#
#
#
# model-00003-of-00004.safetensors:  13% 661M/4.96G [00:27<02:01, 35.5MB/s]
#
#
# model-00001-of-00004.safetensors:  13% 661M/4.90G [00:27<01:43, 40.9MB/s]
# model-00002-of-00004.safetensors:  14% 671M/4.95G [00:27<01:34, 45.4MB/s]
#
# model-00004-of-00004.safetensors:  18% 661M/3.67G [00:28<01:32, 32.6MB/s]
# model-00002-of-00004.safetensors:  14% 682M/4.95G [00:28<01:33, 45.4MB/s]
#
#
#
# model-00003-of-00004.safetensors:  14% 682M/4.96G [00:28<01:32, 46.1MB/s]
#
#
# model-00001-of-00004.safetensors:  14% 671M/4.90G [00:28<01:52, 37.5MB/s]
#
# model-00004-of-00004.safetensors:  18% 671M/3.67G [00:28<01:18, 38.0MB/s]
# model-00002-of-00004.safetensors:  14% 692M/4.95G [00:28<01:20, 52.8MB/s]
#
# model-00004-of-00004.safetensors:  19% 682M/3.67G [00:28<01:10, 42.7MB/s]
#
#
# model-00001-of-00004.safetensors:  14% 682M/4.90G [00:28<01:40, 41.9MB/s]
#
#
#
# model-00003-of-00004.safetensors:  14% 703M/4.96G [00:28<01:15, 56.8MB/s]
# model-00002-of-00004.safetensors:  14% 703M/4.95G [00:28<01:18, 53.9MB/s]
#
#
# model-00001-of-00004.safetensors:  14% 692M/4.90G [00:28<01:29, 46.9MB/s]
#
# model-00004-of-00004.safetensors:  19% 692M/3.67G [00:28<01:04, 46.0MB/s]
#
#
#
# model-00003-of-00004.safetensors:  14% 713M/4.96G [00:28<01:14, 57.0MB/s]
# model-00002-of-00004.safetensors:  14% 713M/4.95G [00:28<01:12, 58.2MB/s]
#
#
#
# model-00003-of-00004.safetensors:  15% 724M/4.96G [00:28<01:10, 60.4MB/s]
#
#
# model-00001-of-00004.safetensors:  14% 703M/4.90G [00:28<01:25, 49.2MB/s]
#
# model-00004-of-00004.safetensors:  19% 703M/3.67G [00:28<01:01, 48.5MB/s]
# model-00002-of-00004.safetensors:  15% 724M/4.95G [00:28<01:11, 59.0MB/s]
#
#
#
# model-00003-of-00004.safetensors:  15% 734M/4.96G [00:28<01:18, 53.9MB/s]
#
#
# model-00001-of-00004.safetensors:  15% 713M/4.90G [00:29<01:31, 45.8MB/s]
#
# model-00004-of-00004.safetensors:  19% 713M/3.67G [00:29<01:07, 43.6MB/s]
# model-00002-of-00004.safetensors:  15% 734M/4.95G [00:29<01:34, 44.8MB/s]
#
# model-00004-of-00004.safetensors:  20% 724M/3.67G [00:33<06:48, 7.22MB/s]
#
#
#
# model-00003-of-00004.safetensors:  15% 744M/4.96G [00:33<09:02, 7.78MB/s]
#
#
# model-00001-of-00004.safetensors:  15% 724M/4.90G [00:33<09:52, 7.06MB/s]
#
#
# model-00001-of-00004.safetensors:  15% 744M/4.90G [00:33<05:29, 12.6MB/s]
#
# model-00004-of-00004.safetensors:  21% 755M/3.67G [00:33<03:07, 15.5MB/s]
# model-00002-of-00004.safetensors:  15% 744M/4.95G [00:33<10:04, 6.96MB/s]
#
# model-00004-of-00004.safetensors:  21% 765M/3.67G [00:33<02:34, 18.8MB/s]
#
#
#
# model-00003-of-00004.safetensors:  15% 755M/4.96G [00:33<07:01, 9.98MB/s]
# model-00002-of-00004.safetensors:  15% 755M/4.95G [00:33<07:18, 9.55MB/s]
#
# model-00004-of-00004.safetensors:  21% 776M/3.67G [00:33<02:07, 22.8MB/s]
#
#
# model-00001-of-00004.safetensors:  16% 765M/4.90G [00:33<03:38, 18.9MB/s]
#
#
#
# model-00003-of-00004.safetensors:  16% 776M/4.96G [00:33<04:07, 16.9MB/s]
# model-00002-of-00004.safetensors:  16% 776M/4.95G [00:34<04:11, 16.6MB/s]
#
# model-00004-of-00004.safetensors:  22% 797M/3.67G [00:34<01:27, 32.8MB/s]
#
#
# model-00001-of-00004.safetensors:  16% 786M/4.90G [00:34<02:36, 26.3MB/s]
#
#
#
# model-00003-of-00004.safetensors:  16% 797M/4.96G [00:34<02:48, 24.7MB/s]
# model-00002-of-00004.safetensors:  16% 786M/4.95G [00:34<03:24, 20.3MB/s]
#
# model-00004-of-00004.safetensors:  22% 807M/3.67G [00:34<01:19, 36.1MB/s]
#
#
# model-00001-of-00004.safetensors:  16% 797M/4.90G [00:34<02:21, 28.9MB/s]
#
#
#
# model-00003-of-00004.safetensors:  16% 807M/4.96G [00:34<02:35, 26.8MB/s]
# model-00002-of-00004.safetensors:  16% 797M/4.95G [00:34<02:59, 23.1MB/s]
#
# model-00004-of-00004.safetensors:  22% 818M/3.67G [00:36<03:12, 14.8MB/s]
#
#
# model-00001-of-00004.safetensors:  16% 807M/4.90G [00:37<06:24, 10.6MB/s]
#
#
#
# model-00003-of-00004.safetensors:  16% 818M/4.96G [00:39<09:10, 7.53MB/s]
# model-00002-of-00004.safetensors:  16% 807M/4.95G [00:39<10:39, 6.48MB/s]
#
#
#
# model-00003-of-00004.safetensors:  17% 828M/4.96G [00:39<07:48, 8.83MB/s]
# model-00002-of-00004.safetensors:  17% 818M/4.95G [00:39<08:27, 8.14MB/s]
#
#
#
# model-00003-of-00004.safetensors:  17% 860M/4.96G [00:39<03:51, 17.7MB/s]
# model-00002-of-00004.safetensors:  17% 849M/4.95G [00:39<03:59, 17.1MB/s]
#
# model-00004-of-00004.safetensors:  23% 828M/3.67G [00:39<06:27, 7.33MB/s]
#
#
# model-00001-of-00004.safetensors:  17% 818M/4.90G [00:39<08:38, 7.89MB/s]
#
#
#
# model-00003-of-00004.safetensors:  18% 881M/4.96G [00:39<02:45, 24.6MB/s]
# model-00002-of-00004.safetensors:  17% 860M/4.95G [00:39<03:22, 20.2MB/s]
#
# model-00004-of-00004.safetensors:  23% 839M/3.67G [00:40<04:53, 9.63MB/s]
#
#
# model-00001-of-00004.safetensors:  17% 828M/4.90G [00:40<06:39, 10.2MB/s]
# model-00002-of-00004.safetensors:  18% 870M/4.95G [00:40<02:49, 24.1MB/s]
#
# model-00004-of-00004.safetensors:  23% 849M/3.67G [00:40<03:44, 12.6MB/s]
#
#
# model-00001-of-00004.safetensors:  17% 839M/4.90G [00:40<05:07, 13.2MB/s]
# model-00002-of-00004.safetensors:  18% 881M/4.95G [00:40<02:18, 29.4MB/s]
#
#
#
# model-00003-of-00004.safetensors:  18% 902M/4.96G [00:40<02:09, 31.4MB/s]
# model-00002-of-00004.safetensors:  18% 891M/4.95G [00:40<02:33, 26.4MB/s]
#
#
#
# model-00003-of-00004.safetensors:  18% 912M/4.96G [00:40<02:23, 28.2MB/s]
#
# model-00004-of-00004.safetensors:  24% 870M/3.67G [00:40<02:40, 17.5MB/s]
#
#
# model-00001-of-00004.safetensors:  18% 860M/4.90G [00:40<03:43, 18.1MB/s]
#
#
#
# model-00003-of-00004.safetensors:  19% 923M/4.96G [00:40<02:02, 33.0MB/s]
#
# model-00004-of-00004.safetensors:  24% 881M/3.67G [00:40<02:12, 21.1MB/s]
# model-00002-of-00004.safetensors:  18% 912M/4.95G [00:40<01:49, 37.0MB/s]
#
#
# model-00001-of-00004.safetensors:  18% 870M/4.90G [00:41<03:10, 21.2MB/s]
#
#
#
# model-00003-of-00004.safetensors:  19% 933M/4.96G [00:41<01:56, 34.5MB/s]
#
# model-00004-of-00004.safetensors:  24% 891M/3.67G [00:41<02:02, 22.6MB/s]
#
#
# model-00001-of-00004.safetensors:  18% 881M/4.90G [00:41<02:53, 23.1MB/s]
# model-00002-of-00004.safetensors:  19% 923M/4.95G [00:41<01:56, 34.7MB/s]
#
#
# model-00001-of-00004.safetensors:  18% 891M/4.90G [00:41<02:18, 29.0MB/s]
#
#
#
# model-00003-of-00004.safetensors:  19% 944M/4.96G [00:41<01:58, 33.9MB/s]
# model-00002-of-00004.safetensors:  19% 933M/4.95G [00:41<01:51, 36.0MB/s]
#
# model-00004-of-00004.safetensors:  25% 902M/3.67G [00:41<02:03, 22.4MB/s]
#
#
# model-00001-of-00004.safetensors:  18% 902M/4.90G [00:42<02:47, 23.8MB/s]
#
#
#
# model-00003-of-00004.safetensors:  19% 954M/4.96G [00:42<02:32, 26.3MB/s]
# model-00002-of-00004.safetensors:  19% 944M/4.95G [00:42<02:13, 30.0MB/s]
#
# model-00004-of-00004.safetensors:  25% 912M/3.67G [00:42<02:20, 19.7MB/s]
#
#
# model-00001-of-00004.safetensors:  19% 912M/4.90G [00:43<03:42, 18.0MB/s]
# model-00002-of-00004.safetensors:  19% 954M/4.95G [00:43<03:18, 20.1MB/s]
#
# model-00004-of-00004.safetensors:  25% 923M/3.67G [00:43<02:25, 18.8MB/s]
#
#
# model-00001-of-00004.safetensors:  19% 923M/4.90G [00:43<03:06, 21.4MB/s]
# model-00002-of-00004.safetensors:  19% 965M/4.95G [00:43<03:06, 21.4MB/s]
#
# model-00004-of-00004.safetensors:  25% 933M/3.67G [00:43<02:14, 20.4MB/s]
#
#
# model-00001-of-00004.safetensors:  19% 933M/4.90G [00:43<02:58, 22.3MB/s]
# model-00002-of-00004.safetensors:  20% 975M/4.95G [00:43<02:42, 24.4MB/s]
#
# model-00004-of-00004.safetensors:  26% 944M/3.67G [00:43<01:57, 23.1MB/s]
#
#
# model-00001-of-00004.safetensors:  19% 944M/4.90G [00:43<02:24, 27.3MB/s]
# model-00002-of-00004.safetensors:  20% 986M/4.95G [00:43<02:15, 29.2MB/s]
#
# model-00004-of-00004.safetensors:  26% 954M/3.67G [00:43<01:34, 28.7MB/s]
#
#
#
# model-00003-of-00004.safetensors:  19% 965M/4.96G [00:44<05:13, 12.8MB/s]
#
#
# model-00001-of-00004.safetensors:  19% 954M/4.90G [00:44<02:02, 32.3MB/s]
# model-00002-of-00004.safetensors:  20% 996M/4.95G [00:44<01:57, 33.8MB/s]
#
# model-00004-of-00004.safetensors:  26% 965M/3.67G [00:44<01:21, 33.2MB/s]
#
#
#
# model-00003-of-00004.safetensors:  20% 975M/4.96G [00:44<04:00, 16.5MB/s]
#
#
# model-00001-of-00004.safetensors:  20% 965M/4.90G [00:44<01:42, 38.4MB/s]
# model-00002-of-00004.safetensors:  20% 1.01G/4.95G [00:44<01:38, 40.1MB/s]
#
# model-00004-of-00004.safetensors:  27% 975M/3.67G [00:44<01:08, 39.6MB/s]
#
#
#
# model-00003-of-00004.safetensors:  20% 986M/4.96G [00:44<03:09, 21.0MB/s]
#
#
# model-00001-of-00004.safetensors:  20% 975M/4.90G [00:44<01:27, 44.9MB/s]
#
# model-00004-of-00004.safetensors:  27% 986M/3.67G [00:44<00:58, 46.1MB/s]
# model-00002-of-00004.safetensors:  21% 1.02G/4.95G [00:44<01:26, 45.5MB/s]
#
#
#
# model-00003-of-00004.safetensors:  20% 996M/4.96G [00:44<02:29, 26.5MB/s]
#
#
# model-00001-of-00004.safetensors:  20% 986M/4.90G [00:44<01:17, 50.7MB/s]
#
# model-00004-of-00004.safetensors:  27% 996M/3.67G [00:44<00:53, 49.7MB/s]
# model-00002-of-00004.safetensors:  21% 1.03G/4.95G [00:44<01:21, 48.4MB/s]
#
#
# model-00001-of-00004.safetensors:  20% 996M/4.90G [00:44<01:12, 53.9MB/s]
#
#
#
# model-00003-of-00004.safetensors:  20% 1.02G/4.96G [00:44<01:40, 39.4MB/s]
#
# model-00004-of-00004.safetensors:  27% 1.01G/3.67G [00:44<00:46, 57.2MB/s]
# model-00002-of-00004.safetensors:  21% 1.04G/4.95G [00:44<01:10, 55.5MB/s]
#
#
# model-00001-of-00004.safetensors:  21% 1.01G/4.90G [00:44<01:04, 60.5MB/s]
#
#
#
# model-00003-of-00004.safetensors:  21% 1.03G/4.96G [00:44<01:37, 40.5MB/s]
#
# model-00004-of-00004.safetensors:  28% 1.02G/3.67G [00:44<00:49, 53.3MB/s]
# model-00002-of-00004.safetensors:  21% 1.05G/4.95G [00:45<01:14, 52.0MB/s]
#
#
# model-00001-of-00004.safetensors:  21% 1.02G/4.90G [00:45<01:08, 56.9MB/s]
#
#
#
# model-00003-of-00004.safetensors:  21% 1.04G/4.96G [00:45<01:23, 47.3MB/s]
#
#
# model-00001-of-00004.safetensors:  21% 1.03G/4.90G [00:45<00:59, 65.2MB/s]
# model-00002-of-00004.safetensors:  21% 1.06G/4.95G [00:45<01:11, 54.6MB/s]
#
#
#
# model-00003-of-00004.safetensors:  21% 1.05G/4.96G [00:45<01:23, 46.9MB/s]
#
# model-00004-of-00004.safetensors:  28% 1.04G/3.67G [00:45<00:46, 56.5MB/s]
# model-00002-of-00004.safetensors:  22% 1.07G/4.95G [00:45<01:05, 59.3MB/s]
#
#
# model-00001-of-00004.safetensors:  21% 1.04G/4.90G [00:45<01:12, 53.0MB/s]
#
# model-00004-of-00004.safetensors:  29% 1.05G/3.67G [00:45<00:42, 61.5MB/s]
#
#
#
# model-00003-of-00004.safetensors:  21% 1.06G/4.96G [00:45<01:20, 48.6MB/s]
# model-00002-of-00004.safetensors:  22% 1.08G/4.95G [00:45<01:06, 58.1MB/s]
#
#
# model-00001-of-00004.safetensors:  21% 1.05G/4.90G [00:45<01:03, 60.4MB/s]
#
# model-00004-of-00004.safetensors:  29% 1.06G/3.67G [00:45<00:39, 66.3MB/s]
#
#
#
# model-00003-of-00004.safetensors:  22% 1.07G/4.96G [00:45<01:10, 55.3MB/s]
#
#
# model-00001-of-00004.safetensors:  22% 1.06G/4.90G [00:45<00:57, 66.8MB/s]
# model-00002-of-00004.safetensors:  22% 1.09G/4.95G [00:45<01:02, 61.9MB/s]
#
# model-00004-of-00004.safetensors:  29% 1.07G/3.67G [00:45<00:35, 73.6MB/s]
#
#
#
# model-00003-of-00004.safetensors:  22% 1.08G/4.96G [00:45<01:02, 62.5MB/s]
# model-00002-of-00004.safetensors:  22% 1.10G/4.95G [00:45<01:06, 58.1MB/s]
#
# model-00004-of-00004.safetensors:  29% 1.08G/3.67G [00:45<00:41, 62.8MB/s]
#
#
# model-00001-of-00004.safetensors:  22% 1.07G/4.90G [00:45<01:10, 54.4MB/s]
#
#
#
# model-00003-of-00004.safetensors:  22% 1.09G/4.96G [00:45<01:05, 59.0MB/s]
#
# model-00004-of-00004.safetensors:  30% 1.09G/3.67G [00:46<00:37, 69.3MB/s]
# model-00002-of-00004.safetensors:  23% 1.12G/4.95G [00:46<00:50, 75.6MB/s]
#
#
# model-00001-of-00004.safetensors:  22% 1.09G/4.90G [00:46<00:59, 64.6MB/s]
#
# model-00004-of-00004.safetensors:  30% 1.10G/3.67G [00:46<00:39, 64.8MB/s]
# model-00002-of-00004.safetensors:  23% 1.13G/4.95G [00:46<01:02, 61.0MB/s]
#
#
#
# model-00003-of-00004.safetensors:  22% 1.11G/4.96G [00:46<01:09, 55.7MB/s]
#
#
# model-00001-of-00004.safetensors:  22% 1.10G/4.90G [00:46<01:02, 60.4MB/s]
#
# model-00004-of-00004.safetensors:  30% 1.11G/3.67G [00:46<00:42, 59.6MB/s]
# model-00002-of-00004.safetensors:  23% 1.14G/4.95G [00:46<00:58, 64.8MB/s]
#
#
#
# model-00003-of-00004.safetensors:  23% 1.12G/4.96G [00:46<01:03, 60.6MB/s]
#
#
# model-00001-of-00004.safetensors:  23% 1.11G/4.90G [00:46<00:56, 67.7MB/s]
#
# model-00004-of-00004.safetensors:  31% 1.13G/3.67G [00:46<00:31, 81.1MB/s]
#
#
# model-00001-of-00004.safetensors:  23% 1.12G/4.90G [00:46<00:57, 65.5MB/s]
# model-00002-of-00004.safetensors:  24% 1.16G/4.95G [00:46<00:54, 69.1MB/s]
#
# model-00004-of-00004.safetensors:  31% 1.14G/3.67G [00:46<00:38, 65.9MB/s]
#
#
#
# model-00003-of-00004.safetensors:  23% 1.14G/4.96G [00:46<01:02, 61.0MB/s]
#
#
# model-00001-of-00004.safetensors:  23% 1.13G/4.90G [00:46<01:03, 59.6MB/s]
# model-00002-of-00004.safetensors:  24% 1.17G/4.95G [00:46<00:58, 64.4MB/s]
#
# model-00004-of-00004.safetensors:  31% 1.15G/3.67G [00:47<00:42, 59.8MB/s]
#
#
#
# model-00003-of-00004.safetensors:  23% 1.15G/4.96G [00:47<01:06, 56.9MB/s]
#
#
# model-00001-of-00004.safetensors:  23% 1.14G/4.90G [00:47<01:06, 56.7MB/s]
# model-00002-of-00004.safetensors:  24% 1.18G/4.95G [00:47<01:03, 59.5MB/s]
#
# model-00004-of-00004.safetensors:  32% 1.16G/3.67G [00:47<00:44, 56.1MB/s]
#
#
#
# model-00003-of-00004.safetensors:  23% 1.16G/4.96G [00:47<01:11, 53.4MB/s]
#
#
# model-00001-of-00004.safetensors:  24% 1.15G/4.90G [00:47<01:13, 50.9MB/s]
# model-00002-of-00004.safetensors:  24% 1.20G/4.95G [00:48<02:36, 24.0MB/s]
# model-00002-of-00004.safetensors:  24% 1.21G/4.95G [00:49<04:26, 14.0MB/s]
#
#
#
# model-00003-of-00004.safetensors:  24% 1.17G/4.96G [00:49<04:57, 12.7MB/s]
#
# model-00004-of-00004.safetensors:  32% 1.17G/3.67G [00:49<03:28, 12.0MB/s]
#
#
# model-00001-of-00004.safetensors:  24% 1.16G/4.90G [00:49<05:21, 11.6MB/s]
# model-00002-of-00004.safetensors:  25% 1.23G/4.95G [00:50<02:40, 23.1MB/s]
#
#
#
# model-00003-of-00004.safetensors:  24% 1.20G/4.96G [00:50<03:01, 20.8MB/s]
#
# model-00004-of-00004.safetensors:  33% 1.20G/3.67G [00:50<02:03, 20.0MB/s]
#
#
# model-00001-of-00004.safetensors:  24% 1.18G/4.90G [00:50<03:07, 19.8MB/s]
# model-00002-of-00004.safetensors:  25% 1.24G/4.95G [00:50<02:12, 27.9MB/s]
#
#
#
# model-00003-of-00004.safetensors:  24% 1.21G/4.96G [00:50<02:29, 25.1MB/s]
#
# model-00004-of-00004.safetensors:  33% 1.21G/3.67G [00:50<01:40, 24.5MB/s]
#
#
# model-00001-of-00004.safetensors:  24% 1.20G/4.90G [00:50<02:32, 24.3MB/s]
#
#
#
# model-00003-of-00004.safetensors:  25% 1.22G/4.96G [00:50<02:01, 30.8MB/s]
# model-00002-of-00004.safetensors:  25% 1.25G/4.95G [00:50<01:52, 33.0MB/s]
#
#
# model-00001-of-00004.safetensors:  25% 1.21G/4.90G [00:50<02:03, 30.0MB/s]
#
#
#
# model-00003-of-00004.safetensors:  25% 1.23G/4.96G [00:50<01:39, 37.5MB/s]
# model-00002-of-00004.safetensors:  25% 1.26G/4.95G [00:50<01:35, 38.6MB/s]
#
#
# model-00001-of-00004.safetensors:  25% 1.22G/4.90G [00:50<01:43, 35.5MB/s]
#
# model-00004-of-00004.safetensors:  33% 1.22G/3.67G [00:50<01:32, 26.7MB/s]
#
#
#
# model-00003-of-00004.safetensors:  25% 1.24G/4.96G [00:50<01:28, 42.1MB/s]
#
# model-00004-of-00004.safetensors:  33% 1.23G/3.67G [00:50<01:14, 32.7MB/s]
# model-00002-of-00004.safetensors:  26% 1.27G/4.95G [00:50<01:25, 43.2MB/s]
#
#
# model-00001-of-00004.safetensors:  25% 1.24G/4.90G [00:50<01:13, 49.6MB/s]
#
#
#
# model-00003-of-00004.safetensors:  25% 1.26G/4.96G [00:50<01:02, 59.2MB/s]
# model-00002-of-00004.safetensors:  26% 1.29G/4.95G [00:50<01:01, 59.5MB/s]
#
#
# model-00001-of-00004.safetensors:  25% 1.25G/4.90G [00:50<01:06, 54.7MB/s]
#
#
#
# model-00003-of-00004.safetensors:  26% 1.27G/4.96G [00:50<00:56, 65.9MB/s]
#
# model-00004-of-00004.safetensors:  34% 1.25G/3.67G [00:50<00:54, 44.7MB/s]
# model-00002-of-00004.safetensors:  26% 1.30G/4.95G [00:51<01:02, 58.0MB/s]
#
#
#
# model-00003-of-00004.safetensors:  26% 1.28G/4.96G [00:51<01:01, 60.2MB/s]
#
# model-00004-of-00004.safetensors:  34% 1.26G/3.67G [00:51<00:53, 45.5MB/s]
#
#
# model-00001-of-00004.safetensors:  26% 1.26G/4.90G [00:51<01:12, 50.4MB/s]
# model-00002-of-00004.safetensors:  26% 1.31G/4.95G [00:51<01:03, 57.5MB/s]
#
#
#
# model-00003-of-00004.safetensors:  26% 1.29G/4.96G [00:51<00:58, 62.5MB/s]
#
#
# model-00001-of-00004.safetensors:  26% 1.27G/4.90G [00:51<01:05, 55.4MB/s]
#
# model-00004-of-00004.safetensors:  35% 1.27G/3.67G [00:51<00:49, 49.0MB/s]
# model-00002-of-00004.safetensors:  27% 1.32G/4.95G [00:51<01:02, 58.1MB/s]
#
#
#
# model-00003-of-00004.safetensors:  26% 1.30G/4.96G [00:51<00:58, 62.3MB/s]
#
#
# model-00001-of-00004.safetensors:  26% 1.28G/4.90G [00:51<01:04, 56.6MB/s]
#
# model-00004-of-00004.safetensors:  35% 1.28G/3.67G [00:51<00:46, 51.5MB/s]
# model-00002-of-00004.safetensors:  27% 1.33G/4.95G [00:51<01:01, 58.9MB/s]
#
#
# model-00001-of-00004.safetensors:  26% 1.29G/4.90G [00:51<01:03, 56.5MB/s]
#
#
#
# model-00003-of-00004.safetensors:  26% 1.31G/4.96G [00:51<01:03, 57.9MB/s]
#
# model-00004-of-00004.safetensors:  35% 1.29G/3.67G [00:51<00:48, 48.8MB/s]
# model-00002-of-00004.safetensors:  27% 1.34G/4.95G [00:56<08:01, 7.49MB/s]
#
#
# model-00001-of-00004.safetensors:  27% 1.30G/4.90G [00:56<08:06, 7.41MB/s]
#
# model-00004-of-00004.safetensors:  35% 1.30G/3.67G [00:56<05:15, 7.51MB/s]
#
#
# model-00001-of-00004.safetensors:  27% 1.31G/4.90G [00:56<05:53, 10.2MB/s]
# model-00002-of-00004.safetensors:  28% 1.36G/4.95G [00:56<04:39, 12.8MB/s]
#
#
#
# model-00003-of-00004.safetensors:  27% 1.32G/4.96G [00:56<08:30, 7.14MB/s]
#
#
# model-00001-of-00004.safetensors:  27% 1.32G/4.90G [00:56<04:21, 13.7MB/s]
#
# model-00004-of-00004.safetensors:  36% 1.32G/3.67G [00:56<03:03, 12.8MB/s]
# model-00002-of-00004.safetensors:  28% 1.37G/4.95G [00:56<03:42, 16.1MB/s]
#
#
# model-00001-of-00004.safetensors:  27% 1.33G/4.90G [00:56<03:17, 18.1MB/s]
#
# model-00004-of-00004.safetensors:  36% 1.33G/3.67G [00:56<02:26, 15.9MB/s]
#
#
#
# model-00003-of-00004.safetensors:  27% 1.33G/4.96G [00:56<06:19, 9.56MB/s]
# model-00002-of-00004.safetensors:  28% 1.38G/4.95G [00:56<02:59, 19.9MB/s]
#
#
#
# model-00003-of-00004.safetensors:  27% 1.34G/4.96G [00:56<04:40, 12.9MB/s]
#
#
# model-00001-of-00004.safetensors:  27% 1.34G/4.90G [00:56<02:35, 22.9MB/s]
#
# model-00004-of-00004.safetensors:  37% 1.34G/3.67G [00:56<01:57, 19.9MB/s]
# model-00002-of-00004.safetensors:  28% 1.39G/4.95G [00:56<02:20, 25.3MB/s]
#
#
# model-00001-of-00004.safetensors:  28% 1.35G/4.90G [00:56<02:01, 29.2MB/s]
#
#
#
# model-00003-of-00004.safetensors:  27% 1.35G/4.96G [00:56<03:33, 16.9MB/s]
#
# model-00004-of-00004.safetensors:  37% 1.35G/3.67G [00:57<02:29, 15.5MB/s]
# model-00002-of-00004.safetensors:  28% 1.41G/4.95G [01:00<07:07, 8.28MB/s]
#
#
# model-00001-of-00004.safetensors:  28% 1.36G/4.90G [01:00<07:11, 8.21MB/s]
#
#
#
# model-00003-of-00004.safetensors:  27% 1.36G/4.96G [01:00<08:17, 7.24MB/s]
#
# model-00004-of-00004.safetensors:  37% 1.36G/3.67G [01:00<04:19, 8.91MB/s]
#
#
# model-00001-of-00004.safetensors:  28% 1.37G/4.90G [01:00<05:11, 11.3MB/s]
#
#
#
# model-00003-of-00004.safetensors:  28% 1.38G/4.96G [01:00<04:38, 12.8MB/s]
# model-00002-of-00004.safetensors:  29% 1.43G/4.95G [01:00<04:09, 14.1MB/s]
#
#
# model-00001-of-00004.safetensors:  28% 1.38G/4.90G [01:00<03:49, 15.4MB/s]
#
# model-00004-of-00004.safetensors:  38% 1.38G/3.67G [01:00<02:33, 14.9MB/s]
# model-00002-of-00004.safetensors:  29% 1.44G/4.95G [01:00<03:20, 17.5MB/s]
#
#
#
# model-00003-of-00004.safetensors:  28% 1.39G/4.96G [01:00<03:42, 16.0MB/s]
#
# model-00004-of-00004.safetensors:  38% 1.39G/3.67G [01:00<02:03, 18.4MB/s]
#
#
# model-00001-of-00004.safetensors:  28% 1.39G/4.90G [01:00<02:55, 20.0MB/s]
# model-00002-of-00004.safetensors:  29% 1.45G/4.95G [01:00<02:40, 21.8MB/s]
#
#
#
# model-00003-of-00004.safetensors:  28% 1.41G/4.96G [01:00<02:58, 20.0MB/s]
#
# model-00004-of-00004.safetensors:  38% 1.41G/3.67G [01:00<01:39, 22.7MB/s]
#
#
# model-00001-of-00004.safetensors:  29% 1.41G/4.90G [01:00<02:16, 25.6MB/s]
# model-00002-of-00004.safetensors:  29% 1.46G/4.95G [01:00<02:08, 27.1MB/s]
#
#
#
# model-00003-of-00004.safetensors:  29% 1.42G/4.96G [01:00<02:20, 25.3MB/s]
#
#
# model-00001-of-00004.safetensors:  29% 1.42G/4.90G [01:00<01:51, 31.2MB/s]
#
# model-00004-of-00004.safetensors:  39% 1.42G/3.67G [01:00<01:22, 27.3MB/s]
#
#
#
# model-00003-of-00004.safetensors:  29% 1.43G/4.96G [01:00<01:55, 30.7MB/s]
# model-00002-of-00004.safetensors:  30% 1.48G/4.95G [01:00<01:25, 40.5MB/s]
#
#
# model-00001-of-00004.safetensors:  29% 1.43G/4.90G [01:00<01:29, 38.9MB/s]
#
# model-00004-of-00004.safetensors:  39% 1.43G/3.67G [01:00<01:06, 33.7MB/s]
# model-00002-of-00004.safetensors:  30% 1.49G/4.95G [01:00<01:14, 46.6MB/s]
#
#
#
# model-00003-of-00004.safetensors:
0MB/s]
#
#
#
# model-00003-of-00004.safetensors:  94% 4.65G/4.96G [02:53<00:06, 48.9MB/s]
#
#
# model-00001-of-00004.safetensors:  93% 4.55G/4.90G [02:53<00:10, 34.5MB/s]
#
#
# model-00001-of-00004.safetensors:  93% 4.56G/4.90G [02:53<00:08, 39.1MB/s]
# model-00002-of-00004.safetensors:  99% 4.88G/4.95G [02:53<00:01, 53.2MB/s]
#
#
#
# model-00003-of-00004.safetensors:  94% 4.67G/4.96G [02:53<00:05, 53.3MB/s]
#
#
#
# model-00003-of-00004.safetensors:  94% 4.68G/4.96G [02:54<00:04, 57.2MB/s]
#
#
# model-00001-of-00004.safetensors:  93% 4.57G/4.90G [02:54<00:08, 41.1MB/s]
# model-00002-of-00004.safetensors:  99% 4.90G/4.95G [02:54<00:00, 59.3MB/s]
#
#
#
# model-00003-of-00004.safetensors:  94% 4.69G/4.96G [02:54<00:04, 58.2MB/s]
# model-00002-of-00004.safetensors:  99% 4.91G/4.95G [02:54<00:00, 62.6MB/s]
#
#
# model-00001-of-00004.safetensors:  93% 4.58G/4.90G [02:54<00:07, 44.4MB/s]
#
#
#
# model-00003-of-00004.safetensors:  95% 4.70G/4.96G [02:54<00:05, 46.7MB/s]
# model-00002-of-00004.safetensors:  99% 4.92G/4.95G [02:56<00:01, 16.1MB/s]
#
#
#
# model-00003-of-00004.safetensors:  95% 4.71G/4.96G [02:56<00:17, 14.8MB/s]
#
#
# model-00001-of-00004.safetensors:  94% 4.59G/4.90G [02:56<00:26, 11.8MB/s]
#
#
#
# model-00003-of-00004.safetensors:  95% 4.73G/4.96G [02:56<00:09, 23.4MB/s]
# model-00002-of-00004.safetensors: 100% 4.94G/4.95G [02:57<00:00, 23.3MB/s]
#
#
# model-00002-of-00004.safetensors: 100% 4.95G/4.95G [02:57<00:00, 27.9MB/s]
#
#
#
# model-00001-of-00004.safetensors:  94% 4.61G/4.90G [02:57<00:14, 19.8MB/s]
#
#
# model-00001-of-00004.safetensors:  95% 4.63G/4.90G [02:57<00:08, 33.0MB/s]
#
#
# model-00001-of-00004.safetensors:  95% 4.67G/4.90G [02:57<00:04, 57.4MB/s]
#
#
#
# model-00003-of-00004.safetensors:  96% 4.74G/4.96G [02:57<00:10, 21.6MB/s]
#
#
# model-00001-of-00004.safetensors:  96% 4.70G/4.90G [02:57<00:02, 77.8MB/s]
#
#
#
# model-00003-of-00004.safetensors:  96% 4.75G/4.96G [02:57<00:07, 26.7MB/s]
#
#
#
# model-00003-of-00004.safetensors:  96% 4.76G/4.96G [02:57<00:06, 32.6MB/s]
#
#
# model-00001-of-00004.safetensors:  96% 4.72G/4.90G [02:57<00:02, 80.0MB/s]
#
#
#
# model-00003-of-00004.safetensors:  96% 4.78G/4.96G [02:58<00:06, 26.9MB/s]
#
#
#
# model-00001-of-00004.safetensors:  97% 4.74G/4.90G [02:58<00:06, 26.6MB/s]
# Fetching 4 files:   0% 0/4 [02:58<?, ?it/s]
# Fetching 4 files:   0% 0/4 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:752: UserWarning: Not enough free disk space to download the file. The expected file size is: 4903.35 MB. The target location /root/.cache/huggingface/hub/models--google--gemma-2-9b-it/blobs only has 0.00 MB free disk space.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:752: UserWarning: Not enough free disk space to download the file. The expected file size is: 4962.22 MB. The target location /root/.cache/huggingface/hub/models--google--gemma-2-9b-it/blobs only has 0.00 MB free disk space.
#   warnings.warn(
#
# model-00003-of-00004.safetensors:  96% 4.78G/4.96G [00:00<?, ?B/s]
#
# model-00003-of-00004.safetensors:  97% 4.79G/4.96G [00:00<00:02, 70.0MB/s]
# model-00001-of-00004.safetensors:  97% 4.74G/4.90G [00:00<00:01, 107MB/s]
# Fetching 4 files:   0% 0/4 [00:00<?, ?it/s]
# 2025-04-30 06:49:21.559 Examining the path of torch.classes raised:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/web/bootstrap.py", line 347, in run
#     if asyncio.get_running_loop().is_running():
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: no running event loop
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/watcher/local_sources_watcher.py", line 217, in get_module_paths
#     potential_paths = extract_paths(module)
#                       ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/watcher/local_sources_watcher.py", line 210, in <lambda>
#     lambda m: list(m.__path__._path),
#                    ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/_classes.py", line 13, in __getattr__
#     proxy = torch._C._get_custom_class_python_wrapper(self.name, attr)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: Tried to instantiate class '__path__._path', but it does not exist! Ensure that it is registered via torch::class_
# 2025-04-30 06:49:21.992 Examining the path of torch.classes raised:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/web/bootstrap.py", line 347, in run
#     if asyncio.get_running_loop().is_running():
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: no running event loop
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/watcher/local_sources_watcher.py", line 217, in get_module_paths
#     potential_paths = extract_paths(module)
#                       ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/watcher/local_sources_watcher.py", line 210, in <lambda>
#     lambda m: list(m.__path__._path),
#                    ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/_classes.py", line 13, in __getattr__
#     proxy = torch._C._get_custom_class_python_wrapper(self.name, attr)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: Tried to instantiate class '__path__._path', but it does not exist! Ensure that it is registered via torch::class_

# %% [markdown]
# アプリケーションの機能としては、チャット機能や履歴閲覧があります。
#
# これらの機能を実現するためには、StreamlitによるUI部分だけではなく、SQLiteを使用したチャット履歴の保存やLLMのモデルを呼び出した推論などの処理を組み合わせることで実現しています。
#
# - **`app.py`**: アプリケーションのエントリーポイント。チャット機能、履歴閲覧、サンプルデータ管理のUIを提供します。
# - **`ui.py`**: チャットページや履歴閲覧ページなど、アプリケーションのUIロジックを管理します。
# - **`llm.py`**: LLMモデルのロードとテキスト生成を行うモジュール。
# - **`database.py`**: SQLiteデータベースを使用してチャット履歴やフィードバックを保存・管理します。
# - **`metrics.py`**: BLEUスコアやコサイン類似度など、回答の評価指標を計算するモジュール。
# - **`data.py`**: サンプルデータの作成やデータベースの初期化を行うモジュール。
# - **`config.py`**: アプリケーションの設定（モデル名やデータベースファイル名）を管理します。
# - **`requirements.txt`**: このアプリケーションを実行するために必要なPythonパッケージ。

# %% [markdown]
# 後片付けとして、使う必要のないngrokのトンネルを削除します。

# %%
from pyngrok import ngrok
ngrok.kill()

# %% [markdown]
# # 03_FastAPI
#
# ディレクトリ「03_FastAPI」に移動します。

# %%
# %cd /content/lecture-ai-engineering/day1/03_FastAPI

# %% [markdown]
# 必要なライブラリをインストールします。

# %%
# %%capture
# !pip install -r requirements.txt

# %% [markdown]
# ngrokとhuggigfaceのトークンを使用して、認証を行います。

# %%
# !ngrok authtoken $$NGROK_TOKEN
# !huggingface-cli login --token $$HUGGINGFACE_TOKEN

# %% [markdown]
# アプリを起動します。
#
# 「02_streamlit_app」から続けて「03_FastAPI」を実行している場合は、モデルのダウンロードが済んでいるため、すぐにサービスが立ち上がります。
#
# 「03_FastAPI」のみを実行している場合は、初回の起動時にモデルのダウンロードが始まるので、モデルのダウンロードが終わるまで数分間待ちましょう。

# %%
# !python app.py

# %% [markdown]
# FastAPIが起動すると、APIとクライアントが通信するためのURL（エンドポイント）が作られます。
#
# URLが作られるのと合わせて、Swagger UIというWebインターフェースが作られます。
#
# Swagger UIにアクセスすることで、APIの仕様を確認できたり、APIをテストすることができます。
#
# Swagger UIを利用することで、APIを通してLLMを動かしてみましょう。

# %% [markdown]
# 後片付けとして、使う必要のないngrokのトンネルを削除します。

# %%
from pyngrok import ngrok
ngrok.kill()
